# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\REINHARD\Covid 19 data se")

# %%
data
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
data.head(100)
# Out:
#    Province/State     Country/Region        Lat       Long        Date  \
# 0             NaN        Afghanistan  33.939110  67.709953  2020-01-22
# 1             NaN            Albania  41.153300  20.168300  2020-01-22
# 2             NaN            Algeria  28.033900   1.659600  2020-01-22
# 3             NaN            Andorra  42.506300   1.521800  2020-01-22
# 4             NaN             Angola -11.202700  17.873900  2020-01-22
# ..            ...                ...        ...        ...         ...
# 95            NaN            Ecuador  -1.831200 -78.183400  2020-01-22
# 96            NaN              Egypt  26.820553  30.802498  2020-01-22
# 97            NaN        El Salvador  13.794200 -88.896500  2020-01-22
# 98            NaN  Equatorial Guinea   1.650800  10.267900  2020-01-22
# 99            NaN            Eritrea  15.179400  39.782300  2020-01-22
#
#     Confirmed  Deaths  Recovered  Active             WHO Region
# ...

# %%
data.tail(100)
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 48968            NaN                Morocco  31.791700  -7.092600  2020-07-27
# 48969            NaN                Namibia -22.957600  18.490400  2020-07-27
# 48970            NaN                  Nepal  28.166700  84.250000  2020-07-27
# 48971          Aruba            Netherlands  12.521100 -69.968300  2020-07-27
# 48972        Curacao            Netherlands  12.169600 -68.990000  2020-07-27
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
data.describe()
# Out:
#                 Lat          Long     Confirmed         Deaths     Recovered  \
# count  49068.000000  49068.000000  4.906800e+04   49068.000000  4.906800e+04
# mean      21.433730     23.528236  1.688490e+04     884.179160  7.915713e+03
# std       24.950320     70.442740  1.273002e+05    6313.584411  5.480092e+04
# min      -51.796300   -135.000000  0.000000e+00       0.000000  0.000000e+00
# 25%        7.873054    -15.310100  4.000000e+00       0.000000  0.000000e+00
# 50%       23.634500     21.745300  1.680000e+02       2.000000  2.900000e+01
# 75%       41.204380     80.771797  1.518250e+03      30.000000  6.660000e+02
# max       71.706900    178.065000  4.290259e+06  148011.000000  1.846641e+06
#
#              Active
# count  4.906800e+04
# mean   8.085012e+03
# std    7.625890e+04
# min   -1.400000e+01
# 25%    0.000000e+00
# 50%    2.600000e+01
# 75%    6.060000e+02
# max    2.816444e+06

# %%
data.describe(include='all')
# Out:
#                       Province/State Country/Region           Lat  \
# count                          14664          49068  49068.000000
# unique                            78            187           NaN
# top     Australian Capital Territory          China           NaN
# freq                             188           6204           NaN
# mean                             NaN            NaN     21.433730
# std                              NaN            NaN     24.950320
# min                              NaN            NaN    -51.796300
# 25%                              NaN            NaN      7.873054
# 50%                              NaN            NaN     23.634500
# 75%                              NaN            NaN     41.204380
# max                              NaN            NaN     71.706900
#
#                 Long        Date     Confirmed         Deaths     Recovered  \
# count   49068.000000       49068  4.906800e+04   49068.000000  4.906800e+04
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
# droping null values
data.dropna()
# Out:
#                      Province/State  Country/Region      Lat      Long  \
# 8      Australian Capital Territory       Australia -35.4735  149.0124
# 9                   New South Wales       Australia -33.8688  151.2093
# 10               Northern Territory       Australia -12.4634  130.8456
# 11                       Queensland       Australia -27.4698  153.0251
# 12                  South Australia       Australia -34.9285  138.6007
# ...                             ...             ...      ...       ...
# 49052                      Anguilla  United Kingdom  18.2206  -63.0686
# 49053        British Virgin Islands  United Kingdom  18.4207  -64.6400
# 49054      Turks and Caicos Islands  United Kingdom  21.6940  -71.7979
# 49059   Falkland Islands (Malvinas)  United Kingdom -51.7963  -59.5236
# 49060     Saint Pierre and Miquelon          France  46.8852  -56.3159
#
#              Date  Confirmed  Deaths  Recovered  Active       WHO Region
# ...

# %%
# Limit to the first 10 entries
subset_data = data.iloc[:10]

plt.figure(figsize=(10, 6))
plt.plot(subset_data['Province/State'].astype(str), subset_data['Lat'], marker='o')
plt.title("COVID-19 Data Set")
plt.xlabel("Province")
plt.ylabel("Latitude")
plt.show()
